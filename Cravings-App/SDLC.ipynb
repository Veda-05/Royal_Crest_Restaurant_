# %%
from sqlalchemy import create_engine
import pandas as pd

# Create a SQLAlchemy engine
engine = create_engine("mysql+mysqlconnector://root:23022006@localhost/SDLCphases")

# SQL query
query = "SELECT * FROM SDLC"  

# Read the SQL table into a DataFrame
df = pd.read_sql(query, con=engine)

# Display the DataFrame
print(df)
# Out:
#                             PHASE1                            PHASE2  PHASE3  \
# 0  PLANNING & REQUIREMENT ANALYSIS             DEFINING REQUIREMENTS  DESIGN
# 1                         Planning                          defining  design
# 2             define project scope            functional requirement     HLD
# 3         set objectives and goals             technical requirement     LLD
# 4                resource planning  requirement reviews and approved
# 5
#
#             PHASE4             PHASE5                      PHASE6
# 0      DEVELOPMENT            TESTING    DEPLOYMENT & MAINTENANCE
# 1      development     system testing  deployment and maintenance
# 2  coding standard     manual testing            release planning
# 3    scalable code  automated testing       deployment automation
# 4  version control                                    maintenance
# 5      code review                                        feedbac

# %%
df
# Out:
#                             PHASE1                            PHASE2  PHASE3  \
# 0  PLANNING & REQUIREMENT ANALYSIS             DEFINING REQUIREMENTS  DESIGN
# 1                         Planning                          defining  design
# 2             define project scope            functional requirement     HLD
# 3         set objectives and goals             technical requirement     LLD
# 4                resource planning  requirement reviews and approved
# 5
#
#             PHASE4             PHASE5                      PHASE6
# 0      DEVELOPMENT            TESTING    DEPLOYMENT & MAINTENANCE
# 1      development     system testing  deployment and maintenance
# 2  coding standard     manual testing            release planning
# 3    scalable code  automated testing       deployment automation
# 4  version control                                    maintenance
# 5      code review                                        feedbac

# %%
i=0
while(i>=0):
    n=input("Enter a phase:")   
    column_data = df[n]
    print(column_data)
# Out:
# 0        DEVELOPMENT
# 1        development
# 2    coding standard
# 3      scalable code
# 4    version control
# 5        code review
# Name: PHASE4, dtype: object
# 0              TESTING
# 1       system testing
# 2       manual testing
# 3    automated testing
# 4
# 5
# Name: PHASE5, dtype: object
# 0      DEPLOYMENT & MAINTENANCE
# 1    deployment and maintenance
# 2              release planning
# 3         deployment automation
# 4                   maintenance
# 5                       feedbac
# Name: PHASE6, dtype: object
